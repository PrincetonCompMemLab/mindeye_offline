# %%
import pickle
import pdb
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import savefig

with open("design_matrices/design_participant1", "rb") as input_file:
    design_participant1 = pickle.load(input_file)
# Out:
# <AxesSubplot:>

# %%
heat = sns.heatmap(design_participant1[1], xticklabels= True)
figure = heat.get_figure()    
figure.savefig('svm_conf.png', dpi=400)

# to do: check at 2 and 5 first
